# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(file_to_load)

# %%
purchase_data_df.tail()
# Out:
#      Purchase ID          SN  Age  Gender  Item ID  \
# 775          775  Aethedru70   21  Female       60
# 776          776      Iral74   21    Male      164
# 777          777  Yathecal72   20    Male       67
# 778          778     Sisur91    7    Male       92
# 779          779   Ennrian78   24    Male       50
#
#                                  Item Name  Price
# 775                                   Wolf   3.54
# 776                       Exiled Doomblade   1.63
# 777  Celeste, Incarnation of the Corrupted   3.46
# 778                           Final Critic   4.19
# 779                                   Dawn   4.60

# %%
purchase_data_df.describe()
# Out:
#        Purchase ID         Age     Item ID       Price
# count   780.000000  780.000000  780.000000  780.000000
# mean    389.500000   22.714103   91.755128    3.050987
# std     225.310896    6.659444   52.697702    1.169549
# min       0.000000    7.000000    0.000000    1.000000
# 25%     194.750000   20.000000   47.750000    1.980000
# 50%     389.500000   22.000000   92.000000    3.150000
# 75%     584.250000   25.000000  138.000000    4.080000
# max     779.000000   45.000000  183.000000    4.990000

# %% [markdown]
# ## Player Count

# %%
# my first way
# unique_players=purchase_data_df.value_counts('SN')
# total_players=unique_players.count()
# total_players


#another way
# len(purchase_data_df.drop_duplicates(subset="SN"))

# %% [markdown]
# * Display the total number of players

# %%
total_players=purchase_data_df["SN"].nunique()

players_df=pd.DataFrame({
    'Total Players': [total_players]
})

players_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# number of unique items - from "Item ID" column
unique_items=purchase_data_df["Item ID"].nunique()
unique_items

# assign variable to number of unique items to later use in df
# unique_items=unique_values.count()
# another way: len(purchase_data_df.value_counts('Item ID'))
# unique_items
# Out:
# 179

# %%
# find total number of purchases
total_purchases=purchase_data_df["Purchase ID"].count()
total_purchases
# Out:
# 780

# %%
# find total revenue, then use to find average price
total_revenue=purchase_data_df["Price"].sum()
avg_price=purchase_data_df["Price"].mean()

# average_price=(total_revenue/total_purchases).round(2)
# use purchase_data_df["Price"].mean()
# average_price.style.format('${.2f}')

# %%
# create df using a list of dic
summary_data = {
    'Number of Unique Items':[unique_items],
    'Average Price':[avg_price],
    'Number of Purchases':[total_purchases],
    'Total Revenue':[total_revenue]
}
summary_df=pd.DataFrame(summary_data)

# format
summary_df.loc[:,'Average Price']=summary_df.loc[:,'Average Price'].map("${:,.2f}".format)
summary_df.loc[:,'Total Revenue']=summary_df.loc[:,'Total Revenue'].map("${:,.2f}".format)
# pd.options.display.float_format = '${:,.2f}'.format --> this makes the format true for the rest of the code. better use above

summary_df
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# create new df with only sn gender
gender_df=purchase_data_df.loc[:,['SN','Gender']]

# # drop duplicates with subset sn
gender_df.drop_duplicates('SN',inplace=True)

# group by genders
gender_grouped_df=gender_df.groupby('Gender').count()

sn_count=gender_grouped_df.loc[:, 'SN'].sum()


# create gender demo percents variable that divides counts by sn count
gender_grouped_df.loc[:,'Percentage of Players']= gender_grouped_df.loc[:, 'SN']/sn_count


# create df with renamed columns, formatting for percent
new_columns={
    
    'SN': 'Total Count'
}

gender_demo_df=gender_grouped_df.rename(columns=new_columns)
gender_demo_df.loc[:, 'Percentage of Players']=gender_demo_df.loc[:,'Percentage of Players'].map("{:,.2%}".format)
gender_demo_df.index.name = None
gender_demo_df.sort_values('Percentage of Players', ascending=False)
# Out:
#                        Total Count Percentage of Players
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# do this one by df.groupby([gender])["Price"].count()
purchase_analysis_df=purchase_data_df.loc[:, ['Gender', 'Price', 'Purchase ID']]
purchase_analysis_df.tail()

# need purchase count = how many purchases made by female/male/undisclosed = count with filter
grouped_pa_df=purchase_analysis_df.groupby(['Gender'])

purchase_count=grouped_pa_df['Purchase ID'].count()

grouped_pa_df.tail()
# Out:
#                     Gender  Price  Purchase ID
# 484  Other / Non-Disclosed   3.94          484
# 549  Other / Non-Disclosed   3.10          549
# 629  Other / Non-Disclosed   2.18          629
# 637  Other / Non-Disclosed   3.45          637
# 731                 Female   1.02          731
# 740                 Female   3.92          740
# 747  Other / Non-Disclosed   3.10          747
# 754                 Female   4.05          754
# 767                 Female   4.88          767
# 774                   Male   4.19          774
# 775                 Female   3.54          775
# 776                   Male   1.63          776
# 777                   Male   3.46          777
# 778                   Male   4.19          778
# 779                   Male   4.60          779

# %%
# total purchase value = sum of price
tot_value=grouped_pa_df['Price'].sum()
tot_value
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
# avg purchase price = tot_value/purchase count
avg_price_gen=tot_value/purchase_count
avg_price_gen
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# dtype: float64

# %%
# avg total purchase per person = tpv/sn count 
# I use a previous df to pull value for sn_count - is there an error issue here? a cleaner way to do this?
sn_count=gender_demo_df.loc[:, 'Total Count']
avg_per_person=tot_value/sn_count
avg_per_person
# Out:
# Gender
# Female                   4.468395
# Male                     4.065372
# Other / Non-Disclosed    4.562727
# dtype: float64

# %%
pa_columns={
    "Purchase Count": purchase_count,
    "Average Purchase Price":avg_price_gen,
    "Total Purchase Value": tot_value,
    "Avg Total Purchase per Person": avg_per_person
}

# use purchase analysis df as a base and rename with new columns
pa_gen_df=pd.DataFrame(pa_columns)
pa_gen_df
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Gender
# Female                               361.94                       4.468395
# Male                                1967.64                       4.065372
# Other / Non-Disclosed                 50.19                       4.562727

# %%
# format
pa_gen_df.loc[:,'Average Purchase Price']=pa_gen_df.loc[:,'Average Purchase Price'].map("${:,.2f}".format)
pa_gen_df.loc[:,'Total Purchase Value']=pa_gen_df.loc[:,'Total Purchase Value'].map("${:,.2f}".format)
pa_gen_df.loc[:,'Avg Total Purchase per Person']=pa_gen_df.loc[:,'Avg Total Purchase per Person'].map("${:,.2f}".format)
pa_gen_df
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %%
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# bins for ages (use pd.cut )
manual_bins = [0, 9.9,14.9, 19.9, 24.9, 29.99, 34.99, 39.99, 100]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
purchase_data_df.loc[:, "Age Group"]=pd.cut(purchase_data_df["Age"], bins=manual_bins, labels=group_names, include_lowest=True)
# purchase_data_df

# purchase_data_df.nunique()  .nunique()

# %%
# create groupby object based on age group
age_df=purchase_data_df.groupby('Age Group')


age_count=age_df['SN'].nunique()
age_count
# Out:
# Age Group
# <10       17
# 10-14     22
# 15-19    107
# 20-24    258
# 25-29     77
# 30-34     52
# 35-39     31
# 40+       12
# Name: SN, dtype: int64

# %%
# calculate numbers and percentages by age group: percentage = agecount/total players *100
age_pct=age_count/total_players

# %%
# Create a summary data frame to hold the results
age_columns={
    "Total Count": age_count,
    "Percentage of Players": age_pct
}

age_demo_df=pd.DataFrame(age_columns)
age_demo_df.dtypes
# Out:
# Total Count                int64
# Percentage of Players    float64
# dtype: object

# %%
# format df
age_demo_df.loc[:, 'Percentage of Players']=age_demo_df.loc[:,'Percentage of Players'].map("{:,.2%}".format)
age_demo_df.index.name = None
age_demo_df
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %%
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Bin the purchase_data data frame by age
manual_bins = [0, 9.9,14.9, 19.9, 24.9, 29.99, 34.99, 39.99, 100]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

purchase_data_df.loc[:, "Age Group"]=pd.cut(purchase_data_df["Age"], bins=manual_bins, labels=group_names, include_lowest=True)

purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                            Frenzied Scimitar   1.56       40+
# 2                                 Final Critic   4.88     20-24
# 3                                  Blindscythe   3.27     20-24
# 4                                         Fury   1.44     20-24
# ..                                         ...    ...       ...
# 775                                       Wolf   3.54     20-24
# 776                           Exiled Doomblade   1.63     20-24
# 777      Celeste, Incarnation of the Corrupted   3.46     20-24
# 778                               Final Critic   4.19       <10
# 779                                       Dawn   4.60     20-24
#
# [780 rows x 8 columns]

# %%
# create a group based off of age bins
age_df=purchase_data_df.groupby('Age Group')

# %%
# Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
age_purchase_cnt=age_df['Purchase ID'].count()

# average purchase price = total price/purchase count
age_cum_price=age_df['Price'].sum()

# cum_purchase=purchase_data_df['Purchase ID'].count()

age_avg_purchase_price=age_cum_price/age_purchase_cnt


# average purchase total per person = total price/age_count

age_avg_pp=age_cum_price/age_count

# %%
# Create a summary data frame to hold the results
age_purchase_columns={
    "Purchase Count": age_purchase_cnt,
    "Average Purchase Price": age_avg_purchase_price,
    "Total Purchase Value": age_cum_price,
    "Avg Total Purchase per Person": age_avg_pp
}

age_summary_df=pd.DataFrame(age_purchase_columns)
age_summary_df.index.name = "Age Ranges"
age_summary_df
# Out:
#             Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Ranges
# <10                     23                3.353478                 77.13
# 10-14                   28                2.956429                 82.78
# 15-19                  136                3.035956                412.89
# 20-24                  365                3.052219               1114.06
# 25-29                  101                2.900990                293.00
# 30-34                   73                2.931507                214.00
# 35-39                   41                3.601707                147.67
# 40+                     13                2.941538                 38.24
#
#             Avg Total Purchase per Person
# Age Ranges
# <10                              4.537059
# 10-14                            3.762727
# 15-19                            3.858785
# 20-24                            4.318062
# 25-29                            3.805195
# 30-34                            4.115385
# 35-39                            4.763548
# 40+                              3.186667

# %%
# # Optional: give the displayed data cleaner formatting

age_summary_df.style.format("${:,.2f}", subset=['Average Purchase Price', 'Total Purchase Value', 'Avg Total Purchase per Person'])
# Out:
# <style  type="text/css" >
# </style><table id="T_9c691b02_53a6_11eb_82a4_f45c8991983d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >
#             </tr>
#             <tr>
#                         <th id="T_9c691b02_53a6_11eb_82a4_f45c8991983dlevel0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow5_col0" class="data row5 col0" >73</td>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_9c691b02_53a6_11eb_82a4_f45c8991983dlevel0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow6_col0" class="data row6 col0" >41</td>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_9c691b02_53a6_11eb_82a4_f45c8991983dlevel0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow7_col0" class="data row7 col0" >13</td>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_9c691b02_53a6_11eb_82a4_f45c8991983drow7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %%
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# 35-39                              $4.76
# 40+                                $3.19

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Run basic calculations to obtain the results in the table below
# pull from purchase_df: sn, purchase count, average purchase price, total purchase value
top_spender_df=purchase_data_df.loc[:, ["SN","Purchase ID", "Price"]]
top_spender_df
# Out:
#                 SN  Purchase ID  Price
# 0          Lisim78            0   3.53
# 1      Lisovynya38            1   1.56
# 2       Ithergue48            2   4.88
# 3    Chamassasya86            3   3.27
# 4        Iskosia90            4   1.44
# ..             ...          ...    ...
# 775     Aethedru70          775   3.54
# 776         Iral74          776   1.63
# 777     Yathecal72          777   3.46
# 778        Sisur91          778   4.19
# 779      Ennrian78          779   4.60
#
# [780 rows x 3 columns]

# %%
# .count by sn to calculate purchase count
spender_count=top_spender_df["SN"].value_counts()
spender_count.head()
# Out:
# Lisosia93      5
# Iral74         4
# Idastidru52    4
# Phaena87       3
# Asur53         3
# Name: SN, dtype: int64

# %%
grouped_spender_df=top_spender_df.groupby('SN')
print(grouped_spender_df)

grouped_spender_df.head()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f9741bff190>
#                 SN  Purchase ID  Price
# 0          Lisim78            0   3.53
# 1      Lisovynya38            1   1.56
# 2       Ithergue48            2   4.88
# 3    Chamassasya86            3   3.27
# 4        Iskosia90            4   1.44
# ..             ...          ...    ...
# 775     Aethedru70          775   3.54
# 776         Iral74          776   1.63
# 777     Yathecal72          777   3.46
# 778        Sisur91          778   4.19
# 779      Ennrian78          779   4.60
#
# [780 rows x 3 columns]

# %%
cum_sn_spending=grouped_spender_df["Price"].sum()
cum_sn_spending
# Out:
# SN
# Adairialis76     2.28
# Adastirin33      4.48
# Aeda94           4.91
# Aela59           4.32
# Aelaria33        1.79
#                  ...
# Yathecal82       6.22
# Yathedeu43       6.02
# Yoishirrala98    4.58
# Zhisrisu83       7.89
# Zontibe81        8.03
# Name: Price, Length: 576, dtype: float64

# %%
# avg purchase price = total price/purchase count
sn_avg_purchase=cum_sn_spending/spender_count
sn_avg_purchase
# Out:
# Adairialis76     2.280000
# Adastirin33      4.480000
# Aeda94           4.910000
# Aela59           4.320000
# Aelaria33        1.790000
#                    ...
# Yathecal82       2.073333
# Yathedeu43       3.010000
# Yoishirrala98    4.580000
# Zhisrisu83       3.945000
# Zontibe81        2.676667
# Length: 576, dtype: float64

# %%
# Create a summary data frame to hold the results
top_spender_columns={
    "Purchase Count": spender_count,
    "Average Purchase Price": sn_avg_purchase,
    "Total Purchase Value": cum_sn_spending
}

top_spender_df=pd.DataFrame(top_spender_columns)
top_spender_df.index.name="SN"

# %%
# Sort the total purchase value column in descending order
top_spender_df=top_spender_df.sort_values('Total Purchase Value', ascending=False)
top_spender_df
# Out:
#                Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                   5                3.792000                 18.96
# Idastidru52                 4                3.862500                 15.45
# Chamjask73                  3                4.610000                 13.83
# Iral74                      4                3.405000                 13.62
# Iskadarya95                 3                4.366667                 13.10
# ...                       ...                     ...                   ...
# Frichjaskan98               1                1.020000                  1.02
# Hala31                      1                1.020000                  1.02
# Aidai61                     1                1.010000                  1.01
# Chanirra79                  1                1.010000                  1.01
# Alo38                       1                1.000000                  1.00
#
# [576 rows x 3 columns]

# %%
# Optional: give the displayed data cleaner formatting
clean_spender_df=top_spender_df.style.format("${:,.2f}", subset=['Average Purchase Price', 'Total Purchase Value'])

# %%
# Display a preview of the summary data frame
clean_spender_df
# Out:
# <style  type="text/css" >
# </style><table id="T_721d0634_53aa_11eb_82a4_f45c8991983d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T
#                         <td id="T_721d0634_53aa_11eb_82a4_f45c8991983drow12_col2" class="data row12 col2" >$10.37</td>
#             </tr>
#             <tr>
#                         <th id="T_721d0634_53aa_11eb_82a4_f45c8991983dlevel0_row13" class="row_heading level0 row13" >Saistyphos30</th>
#                         <td id="T_721d0634_53aa_11eb_82a4_f45c8991983drow13_col0" class="data row13 col0" >3</td>
#                         <td id="T_721d0634_53aa_11eb_82a4_f45c8991983drow13_col1" class="data row13 col1" >$3.44</td>
#                         <td id="T_721d0634_53aa_11eb_82a4_f45c8991983drow13_col2" class="data row13 col2" >$10.33</td>
#             </tr>
#             <tr>
#                         <th id="T_721d0634_53aa_11eb_82a4_f45c8991983dlevel0_row14" class="row_heading level0 row14" >Phyali88</th>
#                         <td id="T_721d0634_53aa_11eb_82a4_f45c8991983drow14_col0" class="data row14 col0" >3</td>

# %%
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 132     Persuasion                                                9
# 108     Extraction, Quickblade Of Trembling Hands                 9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 132     Persuasion                                                 $28.99
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 103     Singed Scalpel                                             $34.80
